# %% [markdown]
# <a href="https://colab.research.google.com/github/JoDeMiro/Ember/blob/main/Interacitve_Note_Book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://towardsdatascience.com/interactive-controls-for-jupyter-notebooks-f5c94829aee6

# %%
import os
from IPython.display import Image
from ipywidgets import interact

# !mkdir images

@interact
def show_images(file=os.listdir('images/')):
    display(Image('images/'+file))
# Out:
# mkdir: cannot create directory ‘images’: File exists
# interactive(children=(Dropdown(description='file', options=('people1.jpg', 'woman1.jpg', 'woman2.jpg', 'people…

# %%
import requests

download_url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv"
target_csv_path = "nba_all_elo.csv"

response = requests.get(download_url)
response.raise_for_status()    # Check that the request was successful
with open(target_csv_path, "wb") as f:
    f.write(response.content)
print("Download ready.")
# Out:
# Download ready.

# %%
import pandas as pd
df = pd.read_csv("nba_all_elo.csv")
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Interact with specification of arguments
@interact
def show_articles_more_than(column=['year_id', 'pts', 'data_game', 'forecast'], 
                            x=(1947, 2021, 1)):
    return df.loc[df[column] > x]
# Out:
# interactive(children=(Dropdown(description='column', options=('year_id', 'pts', 'data_game', 'forecast'), valu…

# %%
@interact
def correlation(column1=list(df.select_dtypes('number').columns),
                column2=list(df.select_dtypes('number').columns)):
  print(f"correlation: {df[column1].corr(df[column2])}")
# Out:
# interactive(children=(Dropdown(description='column1', options=('gameorder', '_iscopy', 'year_id', 'seasongame'…

# %%
sf = df.sample(3)

# %%
sf.head()
# Out:
#         gameorder       game_id lg_id  ...  game_result  forecast notes
# 57973       28987  198711280WSB   NBA  ...            W  0.359237   NaN
# 123168      61585  201403250ORL   NBA  ...            W  0.268001   NaN
# 54649       27325  198601250LAL   NBA  ...            W  0.169598   NaN
#
# [3 rows x 23 columns]
