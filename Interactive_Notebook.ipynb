# %% [markdown]
# <a href="https://colab.research.google.com/github/JoDeMiro/Ember/blob/main/Interactive_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ipywidgets import IntSlider

# %%
slider = IntSlider(value=50)

slider
# Out:
# IntSlider(value=50)

# %%
slider.value = 30

# %%
from ipywidgets import HTML

# %%
text = HTML("The silder value is <b>{}</b>".format(slider.value))

text
# Out:
# HTML(value='The silder value is <b>30</b>')

# %%
def update_html(change):
  text.value = "The silder value is <b>{}</b>".format(slider.value)

# Execute callback whenever the slider value is changed
slider.observe(update_html, 'value')

# %%
import cv2
import matplotlib

from skimage import io, img_as_float
from skimage.filters import gaussian

# %%
pixels = cv2.imread('woman2.jpg')

# %%
matplotlib.pyplot.imshow(pixels)

# %%
filter_cv2 = cv2.GaussianBlur(pixels, (5,5), 0, borderType=cv2.BORDER_CONSTANT)

# %%
filter_skimage = gaussian(pixels, sigma = 5, mode = 'constant', cval = 0.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   """Entry point for launching an IPython kernel.

# %%
matplotlib.pyplot.imshow(filter_cv2)

# %%
matplotlib.pyplot.imshow(filter_skimage)

# %%
slider
# Out:
# IntSlider(value=37)

# %%
matplotlib.pyplot.imshow(gaussian(pixels, sigma = slider.value, mode = 'constant', cval = 0.0))
matplotlib.pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
